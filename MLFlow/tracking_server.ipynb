# %%
import mlflow

# %%
# created a tracking uri
mlflow.set_tracking_uri(uri="http://127.0.0.1:5000")

# %%
mlflow.set_experiment("test_experiment_for_checking_connection")
# Out:
# 2026/02/12 14:31:18 INFO mlflow.tracking.fluent: Experiment with name 'test_experiment_for_checking_connection' does not exist. Creating a new experiment.
# <Experiment: artifact_location='mlflow-artifacts:/1', creation_time=1770886878632, experiment_id='1', last_update_time=1770886878632, lifecycle_stage='active', name='test_experiment_for_checking_connection', tags={}, workspace='default'>

# %%
with mlflow.start_run():
    mlflow.log_metric("Test",1)
    mlflow.log_metric("Feroz",1)
# Out:
# 🏃 View run lyrical-rat-464 at: http://127.0.0.1:5000/#/experiments/1/runs/8d48a621a9b7478989e9b9fc7b01923c
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1

# %%
with mlflow.start_run():
    mlflow.log_metric('test2',1)
    mlflow.log_metric('abrar2',1)
# Out:
# 🏃 View run aged-lark-593 at: http://127.0.0.1:5000/#/experiments/1/runs/d432001a19194c7f869189f0fbc9afd4
# 🧪 View experiment at: http://127.0.0.1:5000/#/experiments/1
