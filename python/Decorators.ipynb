# %%
#  to understand decorators we first need to understand what  the below two are
# * Function copy 
# * closures

# %%
# Fucntion copy

def welcome():
    return "Hello and Welcome"

welcome()
# Out:
# 'Hello and Welcome'

# %%
wel=welcome
wel()
# Out:
# 'Hello and Welcome'

# %%
del welcome
wel()
# Out:
# 'Hello and Welcome'
