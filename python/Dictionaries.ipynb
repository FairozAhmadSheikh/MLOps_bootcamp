# %%
empty_dict={}
empty_dict2=dict()

print(empty_dict)
print(empty_dict2)
# Out:
# {}
# {}

# %%
student={
    "name":"Feroz",
    "age":20,
    "grade":24.4,
}

print(student)
# Out:
# {'name': 'Feroz', 'age': 20, 'grade': 24.4}
