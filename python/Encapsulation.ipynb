# %% [markdown]
# Access Modifiers
#
#     * public
#     * private
#     * protected

# %%
# Public variables 
class Person:
    def __init__(self,name,age):
        self.name=name
        self.age=age

p1=Person("feroz",21)
print(p1.name)
print(p1.age)
# Out:
# feroz
# 21
