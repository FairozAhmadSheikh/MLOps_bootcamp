# %%
# Syntax of functions

def even_odd_check(number):
    """
    This Fucntion checks for numbers in even odd,
    Number : Provide a Number here
    """
    if number%2 == 0:
        print("Even")
    else:
        print("Odd")


even_odd_check(45)
even_odd_check(44)
even_odd_check(2)
# Out:
# Odd
# Even
# Even
