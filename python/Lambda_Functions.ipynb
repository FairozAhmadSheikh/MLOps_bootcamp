# %%
# Syntax for lambda functions

# lambda arguments : expression

# %%
addition= lambda x,y:x+y

print(addition(10,12))
# Out:
# 22

# %%
# even 
even= lambda x:x % 2==0
even(2)
# Out:
# True

# %%
even(1)
# Out:
# False
