# %%
todo_list=['Wash Face','Buy Food','Code ', 'Sleep']

# %%
for value in todo_list:
    print(value)
# Out:
# Wash Face
# Buy Food
# Code
# Sleep

# %%
# Methods of lists

todo_list.append('Repeat')
print(todo_list)
# Out:
# ['Wash Face', 'Buy Food', 'Code ', 'Sleep', 'Repeat']

# %%
todo_list.remove("Sleep")
print(todo_list)
# Out:
# ['Wash Face', 'Buy Food', 'Code ', 'Repeat']

# %%
# Example

grades=[10,12,13,14,15]

grades.append(10)
grades.remove(13)
print(grades)
# Out:
# [10, 12, 14, 15, 10]
# 12.2

# %%
avg_grades=sum(grades)/len(grades)
print(avg_grades)

print(max(grades))
print(min(grades))
