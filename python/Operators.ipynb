# %%
# lOGICAL Operators and or and not 

x =True
y= False

print(x and y) 
print(x or y) 
print(not y)
print(not x)
# Out:
# False
# True
# True
# False

# %%
# Airthamatical operations
a=10
b=20

print(a+b) 
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**2)
