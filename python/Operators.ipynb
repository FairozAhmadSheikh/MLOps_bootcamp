# %%
# lOGICAL Operators and or and not 

x =True
y= False

print(x and y) 
print(x or y) 
print(not y)
print(not x)
# Out:
# False
# True
# True
# False

# %%
# Airthamatical operations
a=10
b=20

print(a+b) 
print(a-b)
print(a*b)
print(a/b)
print(a%b)
print(a**2)
# Out:
# 30
# -10
# 200
# 0.5
# 10
# 100

# %% [markdown]
# # example for all

# %%
a=int(input("Enter first number "))
b=int(input("Enter second number "))
operator=input("Choose and operator  + - / %  * ^ ")

if operator == '+':
    print(a+b)
if operator == '-':
    print(a-b)
if operator == '*':
    print(a*b)
if operator == '/':
    print(a/b)

# %%
a=int(input("Enter first number "))
b=int(input("Enter second number "))
operator=input("Choose and operator  + - / %  * ^ ")

if operator == '+':
    print(a+b)
elif operator == '-':
    print(a-b)
elif operator == '*':
    print(a*b)
elif operator == '/':
    print(a/b)
elif operator == '%':
    print(a%b)
elif operator =='^':
    print(a**2)
    print(b**2)
else:
    print("Choose operator correclty")
# Out:
# 100
# 4

# %% [markdown]
# # Leap Year Example

# %%
year = int(input("Please enter the year: "))
if year % 4 == 0:
    if year % 100 == 0:
        if year % 400 == 0:
            print("It's a leap year")
        else:
            print("Not a leap year")
    else:
        print("It's a leap year")
else:
    print("Not a leap year")
# Out:
# Not a leap year
