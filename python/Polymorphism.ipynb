# %%
# Method Overriding

class Animal:
    def speak(self):
        print("This should have sound of animal")

class Dog(Animal):
     def speak(self):
         print("woof woof")

class Cat(Animal):
    def speak(self):
        print("meow mewo ")

d1=Dog()
c1=Cat()
d1.speak()
c1.speak()
d1.speak()
# Out:
# woof woof
# meow mewo
# woof woof

# %% [markdown]
# Polymorphism with Functions and Methods

# %%
class  Shape:
     def area(self):
          return "The Area of Figrue "

class Rectangle:
    def __init__(self,length,width):
          self.lenght=length
          self.width=width
    def get_area(self):
        return self.lenght*self.width

class Circle:
    def __init__(self,radius):
          self.radius=radius
    def get_area(self):
         return 3.14*self.radius**2

# %%
circ=Circle(30)
circ.get_area()
# Out:
# 2826.0

# %%
rect=Rectangle(10,12)
rect.get_area()
# Out:
# 120
