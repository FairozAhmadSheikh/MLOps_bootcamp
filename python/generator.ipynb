# %%
def square(n):
    for i in range(n):
        return i ** 2

square(3)
# Out:
# 0

# %%
def square(n):
    for i in range(n+1):
        yield i **2

for i in square(3):
    print(i)
# Out:
# 0
# 1
# 4
# 9

# %%
def generator():
    yield 1
    yield 2
    yield 3
gen=generator()
next(gen)
# Out:
# 1

# %%
next(gen)
# Out:
# 2

# %%
next(gen)
# Out:
# 3
