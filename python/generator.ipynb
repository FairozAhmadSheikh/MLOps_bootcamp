# %%
def square(n):
    for i in range(n):
        return i ** 2

square(3)

# %%
def square(n):
    for i in range(n+1):
        yield i **2

for i in square(3):
    print(i)

# %%
def generator():
    yield 1
    yield 2
    yield 3
gen=generator()
next(gen)

# %%
next(gen)

# %%
next(gen)

# %% [markdown]
# # Reading large file using genrators

# %%
def read_large_files():
    with open ('example.txt') as file:
        for line in file:
            yield line

# %%
# Read all file at once
for line in read_large_files():
    print(line)

# %%
next(read_large_files())
# Out:
# 'The standard Lorem Ipsum passage, used since the 1500s\n'
