# %%
my_list=[7,0,0,6,2]
# Simple approach
for i in my_list:
    print(i)
# Out:
# 7
# 0
# 0
# 6
# 2

# %%
iterator=iter(my_list)
next(iterator)
# Out:
# 7

# %%
next(iterator)
# Out:
# 0

# %%
next(iterator)
# Out:
# 0

# %%
next(iterator)
# Out:
# 6

# %%
next(iterator)
# Out:
# 2
