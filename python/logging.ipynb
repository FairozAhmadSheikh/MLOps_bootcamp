# %%
# # way 1 
import logging

# logging.basicConfig(
#     filename='applog.log',
#     filemode='w',
#     level=logging.DEBUG,
#     format='%(asctime)s - %(name)s -  %(levelname)s %(message)s',
#     datefmt='%Y- %m - %d  %H:%M:%S'
# )

# %%
# way 2 
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s %(name)s %(levelname)s  %(message)s',
    datefmt='%Y -%m -%d  %H:%M:%S',
    handlers=[
        logging.FileHandler("applog.log"),
        logging.StreamHandler()
        ]
)
