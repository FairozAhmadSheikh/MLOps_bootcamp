# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series(np.arange(10,101,10))
data
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5     60
# 6     70
# 7     80
# 8     90
# 9    100
# dtype: int64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data={'a':1,'b':2,'c':3}
dict_series=pd.Series(data)
print(dict_series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
series=pd.Series(data,index=index)
series
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %% [markdown]
# # DATAFRAME

# %%
DATA={
    'names':['FAIROZ','SAMEER','HUSSAIN','ABID'],
    'roll':[1,2,3,4],
    'age':[21,22,21,10]
}

df=pd.DataFrame(data=DATA)

# %%
df
# Out:
#      names  roll  age
# 0   FAIROZ     1   21
# 1   SAMEER     2   22
# 2  HUSSAIN     3   21
# 3     ABID     4   10

# %%
# Creating Dataframe from the list of  dictionaries

data=[
    {'name':"fairoz",'age':21,'roll':1},
    {'name':"sameer",'age':22,'roll':2},
    {'name':"hussain",'age':21,'roll':3},
    {'name':"abid",'age':8,'roll':4},
]

data_f=pd.DataFrame(data=data)

# %%
data_f
# Out:
#       name  age  roll
# 0   fairoz   21     1
# 1   sameer   22     2
# 2  hussain   21     3
# 3     abid    8     4

# %%
# Read csv

data=pd.read_csv('customers.csv')
data.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
data.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka       +1-846-706-2218
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        2022-01-30
# ...

# %%
data['Country']
# Out:
# 0                          Chile
# 1                       Djibouti
# 2            Antigua and Barbuda
# 3             Dominican Republic
# 4     Slovakia (Slovak Republic)
#                  ...
# 95                        Guyana
# 96                     Sri Lanka
# 97               Solomon Islands
# 98                         Aruba
# 99                      Honduras
# Name: Country, Length: 100, dtype: object

# %%
data[data['Country']=='Sri Lanka']
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 13     14  A08A8aF8BE9FaD4   Kristine       Cox         Carpenter-Cook
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
#
#             City    Country             Phone 1               Phone 2  \
# 13      Jodyberg  Sri Lanka  786-284-3358x62152  +1-315-627-1796x8074
# 96  New Bradview  Sri Lanka     +1-846-706-2218          605.413.3198
#
#                        Email Subscription Date                     Website
# 13  holdenmiranda@clarke.com        2021-02-08     https://www.brandt.com/
# 96         vkemp@ferrell.com        2021-07-10  https://novak-allison.com/

# %%
data.loc[96]
# Out:
# Index                                        97
# Customer Id                     CeD220bdAaCfaDf
# First Name                                 Lynn
# Last Name                              Atkinson
# Company                   Ware, Burns and Oneal
# City                               New Bradview
# Country                               Sri Lanka
# Phone 1                         +1-846-706-2218
# Phone 2                            605.413.3198
# Email                         vkemp@ferrell.com
# Subscription Date                    2021-07-10
# Website              https://novak-allison.com/
# Name: 96, dtype: object

# %%
data.iloc[96]
# Out:
# Index                                        97
# Customer Id                     CeD220bdAaCfaDf
# First Name                                 Lynn
# Last Name                              Atkinson
# Company                   Ware, Burns and Oneal
# City                               New Bradview
# Country                               Sri Lanka
# Phone 1                         +1-846-706-2218
# Phone 2                            605.413.3198
# Email                         vkemp@ferrell.com
# Subscription Date                    2021-07-10
# Website              https://novak-allison.com/
# Name: 96, dtype: object

# %% [markdown]
# # Accessing specific element

# %%
data.at[96,'Website']    # takes row number and column name
# Out:
# 'https://novak-allison.com/'

# %%
data.iat[96,11]  # takes row number and colummn number
# Out:
# 'https://novak-allison.com/'

# %% [markdown]
# # Data Manipulation with Dataframe

# %%
# adding a column
data['new_column']=np.arange(1,101)

# %%
data['new_column']
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#      ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
# Name: new_column, Length: 100, dtype: int64

# %%
data.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# Remove a column
data.drop('new_column',axis=1,inplace=True)
data.head(2)
# Out:
#    Index      Customer Id First Name Last Name          Company  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter  Rasmussen Group
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano      Vega-Gentry
#
#                 City   Country       Phone 1           Phone 2  \
# 0       East Leonard     Chile  229.077.5154  397.884.0519x718
# 1  East Jimmychester  Djibouti    5153435776  686-620-1820x944
#
#                       Email Subscription Date                     Website
# 0  zunigavanessa@smith.info        2020-08-24  http://www.stephenson.com/
# 1           vmata@colon.com        2021-04-23       http://www.hobbs.com/

# %%
# Update Index column

data['Index']+=10

# %%
data.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0     11  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1     12  1Ef7b82A4CAAD10    Preston    Lozano
# 2     13  6F94879bDAfE5a6        Roy     Berry
# 3     14  5Cef8BFA16c5e3c      Linda     Olsen
# 4     15  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda         +1-539-402-0259    (496)978-3969x58947
# ...

# %%
# delete a row 
data.drop(0,inplace=True)
data
# Out:
#     Index      Customer Id First Name Last Name  \
# 1      12  1Ef7b82A4CAAD10    Preston    Lozano
# 2      13  6F94879bDAfE5a6        Roy     Berry
# 3      14  5Cef8BFA16c5e3c      Linda     Olsen
# 4      15  053d585Ab6b3159     Joanna    Bender
# 5      16  2d08FB17EE273F4      Aimee     Downs
# ..    ...              ...        ...       ...
# 95    106  cb8E23e48d22Eae       Karl     Greer
# 96    107  CeD220bdAaCfaDf       Lynn  Atkinson
# 97    108  28CDbC0dFe4b1Db       Fred    Guerra
# 98    109  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    110  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# 5                      Steele Group      Chavezborough
# ...

# %%
data.describe()
# Out:
#             Index
# count  100.000000
# mean    60.500000
# std     29.011492
# min     11.000000
# 25%     35.750000
# 50%     60.500000
# 75%     85.250000
# max    110.000000
