# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series(np.arange(10,101,10))
data
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5     60
# 6     70
# 7     80
# 8     90
# 9    100
# dtype: int64

# %%
type(data)
# Out:
# pandas.core.series.Series

# %%
data={'a':1,'b':2,'c':3}
dict_series=pd.Series(data)
print(dict_series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
data=[10,20,30]
index=['a','b','c']
series=pd.Series(data,index=index)
series
# Out:
# a    10
# b    20
# c    30
# dtype: int64
