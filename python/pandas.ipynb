# %%
import pandas as pd
import numpy as np

# %%
data=pd.Series(np.arange(10,101,10))
data
# Out:
# 0     10
# 1     20
# 2     30
# 3     40
# 4     50
# 5     60
# 6     70
# 7     80
# 8     90
# 9    100
# dtype: int64

# %%
type(data)
# Out:
# pandas.core.series.Series
