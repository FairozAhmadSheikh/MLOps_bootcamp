# %%
empty_tuple=()
print(empty_tuple)
# Out:
# ()

# %%
type(empty_tuple)
# Out:
# tuple

# %%
tup1=tuple()
print(tup1)
# Out:
# ()

# %%
numbers=tuple([1,2,3,4,5])
print(type(numbers))
# Out:
# <class 'tuple'>

# %%
print(numbers)
# Out:
# (1, 2, 3, 4, 5)

# %%
mixed_tuple=(1,"Hello",3.14,True)
print(type(mixed_tuple))
# Out:
# <class 'tuple'>

# %%
numbers_tup=tuple([1,2,3])
names_tup=tuple(["Feroz","Hussainn","Sameer"])

combined_tuple=numbers_tup +names_tup

print(combined_tuple)
# Out:
# (1, 2, 3, 'Feroz', 'Hussainn', 'Sameer')

# %%
# Tuples Method
print(numbers_tup.count(2))
print(names_tup.index("Sameer"))
# Out:
# 1
# 2
