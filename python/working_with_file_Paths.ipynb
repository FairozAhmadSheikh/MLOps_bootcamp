# %%
# create a new directory
import os
new_directory="package"
os.mkdir(new_directory)
print(f'Directory {new_directory} created successfully')
# Out:
# Directory package created successfully

# %%
# getting all files from a directory
items=os.listdir(".")
items
# Out:
# ['DataSerialization.ipynb',
#  'Dictionaries.ipynb',
#  'example.txt',
#  'file_handling.ipynb',
#  'Filter_Functions.ipynb',
#  'Functions.ipynb',
#  'Lambda_Functions.ipynb',
#  'Lists.ipynb',
#  'Loops.ipynb',
#  'Operators.ipynb',
#  'package',
#  'package_creation',
#  'Sets.ipynb',
#  'tuples.ipynb',
#  'working_with_file_Paths.ipynb']

# %%
# Joining File path

dir_name="package"
file_name='text.txt'

file_path=os.path.join(dir_name,file_name)
file_path
# Out:
# 'package\\text.txt'

# %%
# full path joining
full_file_path=os.path.join(os.getcwd(),dir_name,file_name)
full_file_path
# Out:
# 'c:\\Users\\fairo\\Desktop\\MLOps_bootcamp\\python\\package\\text.txt'

# %%
pathfile='.\example.txt'
if os.path.exists(pathfile):
    print(f'This {pathfile} eists ')
else:
    print('This path does not exist')
# Out:
# This .\example.txt eists
